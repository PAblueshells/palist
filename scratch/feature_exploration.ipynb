# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np

# %%
features_df = pd.read_csv('test_features.csv')
features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.648  0.3920    8    -7.815     0       0.0300         0.718
# 1         0.436  0.0903    0   -11.838     1       0.0311         0.943
# 2         0.629  0.3270   11    -8.285     1       0.0290         0.761
# 3         0.510  0.2940    1    -8.240     0       0.0565         0.283
# 4         0.364  0.3080    4   -13.052     1       0.0402         0.896
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.2370    0.416   80.061  audio_features
# 1          0.000899    0.1050    0.125  102.696  audio_features
# 2          0.000030    0.1030    0.381   74.953  audio_features
# 3          0.000000    0.0825    0.396  121.442  audio_features
# 4          0.002270    0.1230    0.389   73.331  audio_features
#
#                        id                                   uri  \
# 0  08uVt0ax6g380Yti4KeHaE  spotify:track:08uVt0ax6g380Yti4KeHaE
# 1  6tc1gT93ZpMKx3N5AgVljV  spotify:track:6tc1gT93ZpMKx3N5AgVljV
# 2  1TQXIltqoZ5XXyfCbAeSQQ  spotify:track:1TQXIltqoZ5XXyfCbAeSQQ
# 3  2nUqSe3heoIkKnqbteZxPm  spotify:track:2nUqSe3heoIkKnqbteZxPm
# 4  2BOof6lYrGfz6BojJ0aeJd  spotify:track:2BOof6lYrGfz6BojJ0aeJd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/08uVt0ax6g38...
# 1  https://api.spotify.com/v1/tracks/6tc1gT93ZpMK...
# 2  https://api.spotify.com/v1/tracks/1TQXIltqoZ5X...
# 3  https://api.spotify.com/v1/tracks/2nUqSe3heoIk...
# 4  https://api.spotify.com/v1/tracks/2BOof6lYrGfz...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/08uV...       193283
# 1  https://api.spotify.com/v1/audio-analysis/6tc1...       261471
# 2  https://api.spotify.com/v1/audio-analysis/1TQX...       197732
# 3  https://api.spotify.com/v1/audio-analysis/2nUq...       159150
# 4  https://api.spotify.com/v1/audio-analysis/2BOo...       191773
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
numerical_cols = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms',
       'time_signature']

# %%
for col in numerical_cols:
    plt.hist(features_df[col])
    plt.title(col)
    plt.show()

# %%
X = features_df[numerical_cols].values
pca = PCA(n_components=2)
coords = pca.fit_transform(X)
plt.scatter(coords[:,0], coords[:,1])
plt.show()

# %%
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
# Out:
# [9.99999201e-01 7.86749626e-07]
# [8.06508644e+04 7.15364645e+01]
